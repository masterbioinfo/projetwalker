# %%
import os

import ipywidgets as widgets

widgets.Text(
    value= "",
    placeholder='Type something',
    description='Set a cutoff',
    disabled=False
)
# Out:
# Text(value='', description='Set a cutoff', placeholder='Type something')

# %%
#Cutoff
widgets.FloatText(
    value=0.00,
    min=0.00,
    max=2.00,
    step=0.05,
    description='Cutoff',
    disabled=False,
    continuous_update=False
)
# Out:
# FloatText(value=0.0, description='Cutoff', step=0.05)

# %%
#Cutoof
widgets.FloatSlider(
    value=0.0,
    min=0,
    max=2.0,
    step=0.05,
    description='Cutoff:',
    disabled=False,
    continuous_update=False,
    orientation='vertical',
    readout=True,
)
# Out:
# FloatSlider(value=0.0, continuous_update=False, description='Cutoff:', max=2.0, orientation='vertical', step=0.05)

# %%
import os

import ipywidgets as widgets

residuNotRetained = "bla"
with open("../projetwalker/data/listes/listPP/residus_not_retained.txt", "r") as fileLoad:
    for line in fileLoad:
        residuNotRetained = residuNotRetained + line

widgets.Textarea(
    #Change "value" by list of residu not retained in the study.
    value=residuNotRetained,
    placeholder='Type something',
    description='String:',
    disabled=True
)
# Out:
# Textarea(value='bla', description='String:', disabled=True, placeholder='Type something')

# %%
import os

import ipywidgets as widgets

class Titration(object):
    
    def __init__(self):
        self.checkPlot = False
        self.plotName = None
    
def checkbox(self):
    widgets.Checkbox(
        value=plot.checkPlot,
        description=plot.plotName,
        disabled=False
        )

plotList = list()
i = 0
while i < 10 : 
    plot = Titration()
    plot.plotName = "Plot {0}".format(i)
    plotList.append(plot)
    i += 1
    

plot = Titration()
plot.plotName = "All plots"
plotList.append(plot)  

#Plot nb 1
widgets.Checkbox(
    value=plotList[1].checkPlot,
    description=plotList[1].plotName,
    disabled=False
    )

#Plot all
widgets.Checkbox(
    value=plot.checkPlot,
    description=plot.plotName,
    disabled=False
    )
# Out:
# Checkbox(value=False, description='All plots')

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

class Titration(object):
    
    def __init__(self, checkPlot, plotName, plotValue):
        self.checkPlot = checkPlot
        self.plotName = plotName
        self.plotValue = plotValue

plotList = list()
i = 0
while i <= 10 : 
    plot = Titration(False, "Plot {0}".format(i), i)
    plotList.append(plot)
    i += 1
    
plot = Titration(False, "All", "all")
plot.plotName = "All plots"
plotList.append(plot) 


widgets.RadioButtons(
    options=[plotList[0].plotName, plotList[1].plotName, plotList[2].plotName, plotList[3].plotName, plotList[4].plotName, plotList[5].plotName, plotList[6].plotName, plotList[7].plotName, plotList[8].plotName, plotList[9].plotName, plotList[10].plotName, plotList[11].plotName],
#     value='pineapple',
    description='Plot selection:',
    disabled=False
)
# Out:
# RadioButtons(description='Plot selection:', options=('Plot 0', 'Plot 1', 'Plot 2', 'Plot 3', 'Plot 4', 'Plot 5', 'Plot 6', 'Plot 7', 'Plot 8', 'Plot 9', 'Plot 10', 'All plots'), value='Plot 0')

# %%
import difflib
import random
import requests
import ipywidgets as widgets


def multi_checkbox_widget(descriptions):
    """ Widget with a search field and lots of checkboxes """
    search_widget = widgets.Text()
    options_dict = {description: widgets.Checkbox(description=description, value=False) for description in descriptions}
    options = [options_dict[description] for description in descriptions]
    options_widget = widgets.VBox(options, layout={'overflow': 'scroll'})
    multi_select = widgets.VBox([search_widget, options_widget])

    # Wire the search field to the checkboxes
    def on_text_change(change):
        search_input = change['new']
        if search_input == '':
            # Reset search field
            new_options = [options_dict[description] for description in descriptions]
        else:
            # Filter by search field using difflib.
            close_matches = difflib.get_close_matches(search_input, descriptions, cutoff=0.0)
            new_options = [options_dict[description] for description in close_matches]
        options_widget.children = new_options

    search_widget.observe(on_text_change, names='value')
    return multi_select

# Example of using the widget


class Titration(object):
    
    def __init__(self, checkPlot, plotName, plotValue):
        self.checkPlot = checkPlot
        self.plotName = plotName
        self.plotValue = plotValue

plotList = list()
i = 0
while i <= 10 : 
    plot = Titration(False, "Plot {0}".format(i), i)
    plotList.append(plot)
    i += 1
plot = Titration(False, "All", "all")
plot.plotName = "All plots"
plotList.append(plot) 

# Get lots of words for our options 
words_url = 'https://svnweb.freebsd.org/csrg/share/dict/words?view=co&content-type=text/plain'
response = requests.get(words_url)
response.raise_for_status()
words = response.text
words = set([word.lower() for word in words.splitlines()])
descriptions = [plot.plotName for plot in plotList]

multi_checkbox_widget(descriptions)

# %%
widgets.ToggleButton(
    value=False,
    description='Validate',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Description',
    icon='check'
)
# Out:
# ToggleButton(value=False, description='Validate', icon='check', tooltip='Description')

# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
from ipywidgets import *
from IPython.display import display
from IPython.html import widgets
plt.style.use('ggplot')

NUMBER_OF_PINGS = 4

# displaying the text widget
text = widgets.Text(description="Set a cutoff", width=200)
display(text)

# preparing the plot 
data = pd.DataFrame()
x = range(1,NUMBER_OF_PINGS+1)
plots = dict()
fig, ax = plt.subplots()
plt.xlabel('iterations')
plt.ylabel('ms')
plt.xticks(x)
plt.show()

# preparing a container to put in created checkbox per domain
checkboxes = []
cb_container = widgets.HBox()
display(cb_container)

# add button that updates the graph based on the checkboxes
button = widgets.Button(description="Update the graph")

# function to deal with the added domain name
def handle_submit(sender):
    # a part of the magic inside python : pinging
    res = !ping -c {NUMBER_OF_PINGS} {text.value}
    hits = res.grep('64 bytes').fields(-2).s.replace("time=","").split()
    if len(hits) == 0:
        print("Domain gave error on pinging")
    else:
         # rebuild plot based on ping result
        data = hits
        data = data.astype(float)
        plots, = ax.plot(x, data, label=text.value)
        plt.legend()
        plt.draw()
        # add a new checkbox for the new domain
        checkboxes.append(widgets.Checkbox(description = text.value, value=True, width=90))
        cb_container.children=[i for i in checkboxes]
        if len(checkboxes) == 1:
            display(button)

# function to deal with the checkbox update button       
def on_button_clicked(b):
    for c in cb_container.children:
        if not c.value:
            plots.set_visible(False)
        else:
            plots.set_visible(True)
    plt.legend()
    plt.draw()

button.on_click(on_button_clicked)
text.on_submit(handle_submit)
plt.show()
# Out:
# /home/n0um5/anaconda3/lib/python3.6/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# Text(value='', description='Set a cutoff')
# <img src="data:image/png;base64,..." width="640">
# HBox()

# %%
from ipywidgets import Button, HBox, VBox

words = ['2D shift map', '2D shift map zoom', 'Histrogram', 'Select residu']
items = [Button(description=w) for w in words]
left_box = HBox([items[0], items[1]])
right_box = HBox([items[2], items[3]])
VBox([left_box, right_box])

# %%
from ipywidgets import Layout, Button, Box, FloatText, Textarea, Dropdown, Label, IntSlider
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import os


class Titration(object):
    
    def __init__(self, checkPlot, plotName, plotValue):
        self.checkPlot = checkPlot
        self.plotName = plotName
        self.plotValue = plotValue

plotList = list()
i = 0
while i <= 10 : 
    plot = Titration(False, "Plot {0}".format(i), i)
    plotList.append(plot)
    i += 1
    
plot = Titration(False, "All plots", "all")
plotList.append(plot) 

residuNotRetained = "bla"
with open("../projetwalker/data/listes/listPP/residus_not_retained.txt", "r") as fileLoad:
    for line in fileLoad:
        residuNotRetained = residuNotRetained + line

#Affichage
form_item_layout = Layout(
    display='flex',
    flex_flow='column',
    justify_content='space-between'
)

form_items = [
    Box([Label(value=''),
        widgets.ToggleButtons(options=['2D shift map', '2D map zoom', 'Histograms'], disabled=False, button_style='', 
        tooltips=['2D shift map', '2D map zoom', 'Histograms'])]),
    Box([Label(value=''), 
        widgets.RadioButtons(options=[plotList[0].plotName, plotList[1].plotName, plotList[2].plotName, 
        plotList[3].plotName, plotList[4].plotName, plotList[5].plotName, plotList[6].plotName, plotList[7].plotName, 
        plotList[8].plotName, plotList[9].plotName, plotList[10].plotName, plotList[11].plotName],
        description='Select plot', disabled=False)], layout=form_item_layout),
    Box([Label(value='Select cutoff'), FloatSlider(min=0.0, max=2.0, step=0.05)], layout=form_item_layout),
    Box([Label(value=''),
        widgets.ToggleButton(value=False, description='Validate', disabled=False, button_style='', 
        tooltip='Description', icon='check')], layout=form_item_layout),
    Box([Label(value=''),
        widgets.ToggleButton(value=False, description='Save job', disabled=False, button_style='', 
        tooltip='Description')], layout=form_item_layout),
    Box([Label(value=''),
        widgets.ToggleButton(value=False, description='Save image', disabled=False, button_style='', 
        tooltip='Description')], layout=form_item_layout),
    Box([Label(value='Console'),
        widgets.Textarea(value=residuNotRetained, placeholder='Type something', description='String:', disabled=True)], 
        layout=form_item_layout)]

form = Box(form_items, layout=Layout(
    display='flex',
    flex_flow='row',
    border='solid 2px',
    align_items='flex-start',
    width='100%',
    height='100%'
))
form
# Out:
# Box(children=(Box(children=(Label(value=''), ToggleButtons(options=('2D shift map', '2D map zoom', 'Histograms'), tooltips=['2D shift map', '2D map zoom', 'Histograms'], value='2D shift map'))), Box(children=(Label(value=''), RadioButtons(description='Select plot', options=('Plot 0', 'Plot 1', 'Plot 2', 'Plot 3', 'Plot 4', 'Plot 5', 'Plot 6', 'Plot 7', 'Plot 8', 'Plot 9', 'Plot 10', 'All plots'), value='Plot 0')), layout=Layout(display='flex', flex_flow='column', justify_content='space-between')), Box(children=(Label(value='Select cutoff'), FloatSlider(value=0.0, max=2.0, step=0.05)), layout=Layout(display='flex', flex_flow='column', justify_content='space-between')), Box(children=(Label(value=''), ToggleButton(value=False, description='Validate', icon='check', tooltip='Description')), layout=Layout(display='flex', flex_flow='column', justify_content='space-between')), Box(children=(Label(value=''), ToggleButton(value=False, description='Save job', tooltip='Description')), layout=Lay
# ...

# %%
widgets.Dropdown(
    options=['1', '2', '3'],
    value='1',
    description='Number:',
    disabled=False,
)
# Out:
# Dropdown(description='Number:', options=('1', '2', '3'), value='1')

# %%
from matplotlib import pyplot as plt
import ipywidgets as w
from IPython.display import display, clear_output

#sliders = [w.IntSlider(), w.IntSlider(), w.IntSlider()]
#o = w.Output()

def update_chart(change):
    with o:
        clear_output()
        plt.plot([s.value for s in sliders])
        plt.show()
for s in sliders:
    s.observe(update_chart, 'value')
update_chart(None)
w.HBox([w.VBox(sliders), o])
